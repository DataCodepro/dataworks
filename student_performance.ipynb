# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import chart_studio.plotly as py
import cufflinks as cf
import seaborn as sns
import plotly.express as px
import missingno as msno
# %matplotlib inline

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
student = pd.read_csv('StudentsPerformance.csv')

# %%
student.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
student.shape
# Out:
# (1000, 8)

# %%
student.isnull().sum().sort_values()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
student['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
student['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
student['lunch'].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
student['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'race/ethnicity',y='math score', data =student,hue = 'gender')


plt.show()

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'race/ethnicity',y='reading score', data =student,hue = 'gender')


plt.show()

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'race/ethnicity',y='writing score', data =student,hue = 'gender')


plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot('race/ethnicity', data =student,hue = 'gender')


plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.figure(figsize=(12,8))
sns.countplot('parental level of education', data =student,hue = 'gender')


plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.pairplot(student)

# %%
sns.countplot(x='race/ethnicity',data=student,hue='gender')
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.countplot(x = "parental level of education", data= student,hue="gender")
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='count'>

# %%
plt.figure(figsize=(20,20))
sns.countplot(x = "lunch", data= student,hue="gender")
# Out:
# <AxesSubplot:xlabel='lunch', ylabel='count'>

# %%
plt.figure(figsize=(25,25))
sns.violinplot(x = 'math score',y = 'reading score',data = student, hue= 'gender')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='reading score'>

# %%
sns.jointplot(x='math score',y='reading score',data=student,kind='reg')

# %%
sns.jointplot(x='math score',y='writing score',data=student,kind='reg')

# %%
sns.jointplot(x='reading score',y='writing score',data=student,kind='reg')

# %%
sns.regplot(x='math score', y='writing score',data=student)
# Out:
# <AxesSubplot:xlabel='math score', ylabel='writing score'>

# %%
sns.regplot(x='math score', y='reading score',data=student)
# Out:
# <AxesSubplot:xlabel='math score', ylabel='reading score'>

# %%
sns.regplot(x='reading score', y='writing score',data=student)
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='writing score'>

# %%
msno.bar(student,color= 'b')
# Out:
# <AxesSubplot:>

# %%
student.describe().transpose()
# Out:
#                 count    mean        std   min    25%   50%   75%    max
# math score     1000.0  66.089  15.163080   0.0  57.00  66.0  77.0  100.0
# reading score  1000.0  69.169  14.600192  17.0  59.00  70.0  79.0  100.0
# writing score  1000.0  68.054  15.195657  10.0  57.75  69.0  79.0  100.0

# %%
student.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000
